# %%
from preload import *
import statsmodels.formula.api as smf
linewidth=3
ticklabel_fontsize=25
label_fontsize=25
title_fontsize=22
title_x_postion=-.18
ylabel_y_postion=-1
labelpad=16
plt.rcParams['font.family']=['Helvetica']

# %%
fig = plt.figure(figsize=(6,5),facecolor='white')
#data = pd.DataFrame({'x':X,'y':Y,'z':Z[:,1]-Y})
data = pd.read_csv('./FigureData/FigureData4_draw.csv')
plt.errorbar(data['x'],data['y'],yerr=data['z'],color='gray',
             elinewidth=2,ecolor='gray',
             capsize=5,mew=5,fmt='o',
             mfc='steelblue',mec='steelblue',alpha=.8)
plt.vlines(1994,-2,5,color='gray',linestyle='--')
plt.hlines(0,1970,2020,color='gray',linestyle=':')
plt.ylim(-.6,.6)
plt.yticks([-.6,-.4,-.2,0,.2,.4,.6])
plt.xlim(1989-.5,1999+.5)
plt.ylabel('Changes in reference age (years)',fontsize=label_fontsize-5)
plt.xlabel('Years',fontsize=label_fontsize)
plt.text(1994,.45,'The End of\n Mandatory Retirement',
         ha='center',fontsize=label_fontsize-2,color='gray')
tick_label_size=8
ax=plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=ticklabel_fontsize-2)
ax.yaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.xaxis.set_minor_locator(plt.MultipleLocator(1))
ax.xaxis.set_major_locator(plt.MultipleLocator(2))
plt.savefig('./fig/F4.pdf',bbox_inches='tight')
